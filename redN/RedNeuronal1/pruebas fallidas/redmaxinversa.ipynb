# %%
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MaxAbsScaler
import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score
from scipy.stats import pearsonr
from sklearn.preprocessing import RobustScaler

# %%
files = [file for file in os.listdir('./parametros')]

param = pd.DataFrame()
for file in files:
  df = pd.read_csv('./parametros/'+file)
  param = pd.concat([param, df], axis= 0)

# %% [markdown]
# Como los intentos pasados de la red no han salido como hemos querido, lo que se buscará aqui es tomar únicamente los valores máximos de cada 600 datos, que es una gráfica de las que obtuvimos previamente

# %% [markdown]
# Dividir el dataframe en 64 sub dataframes de igual longitud (600)

# %%
#Contiene todos los subdataframes
sub_dfs = np.array_split(param, 64)

# %% [markdown]
# Crear DataFrame vacío que contendrá los valores máximos

# %%
df_max = pd.DataFrame(columns=['Índice de absorción MAX', 'Longitud de onda MAX', 'Fracción Volumen', 'Espesor de la película (nm)', 'Radio (nm)'])

# %%
for i, sub_df in enumerate(sub_dfs):
    # Encontrar el valor máximo de índice de refracción y su longitud de onda correspondiente
    fila_max = sub_df.loc[sub_df['Índice de absorción'].idxmax()]
    # Imprimir el valor máximo y su correspondiente en la columna 1
    df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'], 
                            'Longitud de onda MAX': fila_max['Longitud de onda'],
                            'Fracción Volumen': fila_max['Fracvol'],
                            'Espesor de la película (nm)': fila_max['Espesor de la película (nm)'],
                            'Radio (nm)': fila_max['Radio (nm)']}, ignore_index=True)
# Out:
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],
# C:\Users\PcR\AppData\Local\Temp\ipykernel_15168\2759968200.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_max = df_max.append({'Índice de absorción MAX': fila_max['Índice de absorción'],

# %%
df_max
# Out:
#     Índice de absorción MAX  Longitud de onda MAX  Fracción Volumen  \
# 0                  0.016685                 301.0               1.0
# 1                  0.016949                 301.0               1.0
# 2                  0.017202                 301.0               1.0
# 3                  0.017405                 301.0               1.0
# 4                  0.017537                 301.0               1.0
# ..                      ...                   ...               ...
# 59                 0.017540                 301.0               1.0
# 60                 0.017539                 301.0               1.0
# 61                 0.017539                 301.0               1.0
# 62                 0.017538                 301.0               1.0
# 63                 0.017537                 301.0               1.0
#
#     Espesor de la película (nm)  Radio (nm)
# 0                         100.0        10.0
# 1                         105.0        10.0
# 2                         110.0        10.0
# 3                         115.0        10.0
# 4                         120.0        10.0
# ..                          ...         ...
# 59                        120.0         5.0
# 60                        120.0         6.0
# 61                        120.0         7.0
# 62                        120.0         8.0
# 63                        120.0         9.0
#
# [64 rows x 5 columns]

# %% [markdown]
# # Red que tiene de input longitud de onda y coeficiente de absorción y de output, fracción volumen, espesor de la película y radio

# %%
# Seleccionar las columnas de entrada y salida
salida = ['Fracción Volumen', 'Radio (nm)', 'Espesor de la película (nm)']
entrada = ['Longitud de onda MAX', 'Índice de absorción MAX']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(df_max[entrada], df_max[salida], test_size=0.2, random_state=42)

# %%
# Crear objetos StandardScaler para normalizar los datos de entrada y salida
scaler_X = RobustScaler()
scaler_y = RobustScaler()

# Ajustar los objetos scaler a los datos de entrenamiento
scaler_X.fit(X_train)
scaler_y.fit(y_train)

# Aplicar la normalización a los datos de entrenamiento y prueba
X_train_norm = scaler_X.transform(X_train)
X_test_norm = scaler_X.transform(X_test)
y_train_norm = scaler_y.transform(y_train)
y_test_norm = scaler_y.transform(y_test)

# %%
# Definir la estructura de la red neuronal
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(2,)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(3)
])

# Compilar la red neuronal
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=optimizer, loss='mean_absolute_error')

# %%
history = model.fit(X_train_norm, y_train_norm, epochs=100, batch_size=4, validation_split=0.2)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 11ms/step - loss: 6.4250 - val_loss: 15.4930
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.5570 - val_loss: 11.6633
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 4.3507 - val_loss: 15.9849
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 6.0656 - val_loss: 8.5132
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 4.2118 - val_loss: 4.9942
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1900 - val_loss: 4.9152
# Epoch 7/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.9540 - val_loss: 3.8670
# Epoch 8/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5976 - val_loss: 2.8524
# Epoch 9/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3902 - val_loss: 2.4175
# Epoch 10/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5344 - val_loss: 2.7169
# Epoch 11/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5306 - val_loss: 3.2533
# Epoch 12/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5748 - val_loss: 3.6675
# Epoch 13/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5055 - val_loss: 2.9329
# Epoch 14/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3892 - val_loss: 2.4193
# Epoch 15/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1593 - val_loss: 3.2079
# Epoch 16/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3413 - val_loss: 2.1538
# Epoch 17/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1254 - val_loss: 2.7138
# Epoch 18/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1875 - val_loss: 2.3166
# Epoch 19/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2636 - val_loss: 2.5065
# Epoch 20/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2242 - val_loss: 2.2433
# Epoch 21/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1378 - val_loss: 2.0030
# Epoch 22/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0578 - val_loss: 2.3479
# Epoch 23/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1515 - val_loss: 2.2165
# Epoch 24/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1761 - val_loss: 1.9728
# Epoch 25/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2245 - val_loss: 2.1785
# Epoch 26/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0398 - val_loss: 1.9147
# Epoch 27/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0769 - val_loss: 2.1396
# Epoch 28/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2110 - val_loss: 2.3218
# Epoch 29/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1350 - val_loss: 2.1439
# Epoch 30/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2361 - val_loss: 2.2759
# Epoch 31/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2272 - val_loss: 3.4681
# Epoch 32/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5575 - val_loss: 2.3704
# Epoch 33/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3853 - val_loss: 3.5409
# Epoch 34/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5234 - val_loss: 2.6722
# Epoch 35/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1426 - val_loss: 1.9557
# Epoch 36/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1986 - val_loss: 2.0730
# Epoch 37/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1200 - val_loss: 2.9176
# Epoch 38/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1011 - val_loss: 2.3984
# Epoch 39/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2191 - val_loss: 2.3396
# Epoch 40/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0957 - val_loss: 2.1698
# Epoch 41/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1204 - val_loss: 1.8478
# Epoch 42/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1520 - val_loss: 2.1498
# Epoch 43/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2950 - val_loss: 2.4639
# Epoch 44/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3546 - val_loss: 2.5138
# Epoch 45/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0621 - val_loss: 2.0863
# Epoch 46/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0124 - val_loss: 2.5007
# Epoch 47/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1826 - val_loss: 3.2825
# Epoch 48/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3804 - val_loss: 2.2172
# Epoch 49/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9991 - val_loss: 2.0321
# Epoch 50/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1220 - val_loss: 2.0395
# Epoch 51/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0099 - val_loss: 2.3533
# Epoch 52/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0667 - val_loss: 2.5815
# Epoch 53/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1191 - val_loss: 2.2227
# Epoch 54/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0070 - val_loss: 2.1604
# Epoch 55/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9499 - val_loss: 2.1284
# Epoch 56/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0266 - val_loss: 2.0768
# Epoch 57/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0159 - val_loss: 2.2867
# Epoch 58/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0372 - val_loss: 2.1745
# Epoch 59/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0065 - val_loss: 1.8848
# Epoch 60/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9568 - val_loss: 1.8648
# Epoch 61/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9290 - val_loss: 2.3591
# Epoch 62/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1149 - val_loss: 2.1550
# Epoch 63/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9494 - val_loss: 2.1661
# Epoch 64/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9364 - val_loss: 1.8308
# Epoch 65/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9901 - val_loss: 2.0912
# Epoch 66/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9599 - val_loss: 1.8716
# Epoch 67/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9524 - val_loss: 1.8807
# Epoch 68/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9101 - val_loss: 2.0215
# Epoch 69/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0628 - val_loss: 2.4401
# Epoch 70/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9882 - val_loss: 2.8884
# Epoch 71/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2571 - val_loss: 2.2099
# Epoch 72/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0399 - val_loss: 2.0678
# Epoch 73/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9748 - val_loss: 2.2505
# Epoch 74/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0080 - val_loss: 1.9696
# Epoch 75/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9556 - val_loss: 1.8630
# Epoch 76/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8856 - val_loss: 1.9867
# Epoch 77/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9190 - val_loss: 1.8827
# Epoch 78/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8557 - val_loss: 1.7928
# Epoch 79/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8738 - val_loss: 1.8543
# Epoch 80/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8758 - val_loss: 1.8752
# Epoch 81/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8798 - val_loss: 1.9022
# Epoch 82/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8892 - val_loss: 1.8223
# Epoch 83/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8475 - val_loss: 1.7510
# Epoch 84/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8737 - val_loss: 2.1789
# Epoch 85/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9440 - val_loss: 1.8014
# Epoch 86/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8667 - val_loss: 1.8590
# Epoch 87/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8662 - val_loss: 1.9099
# Epoch 88/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0717 - val_loss: 2.4795
# Epoch 89/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1442 - val_loss: 2.0994
# Epoch 90/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9782 - val_loss: 2.1935
# Epoch 91/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9753 - val_loss: 2.3776
# Epoch 92/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0234 - val_loss: 2.4667
# Epoch 93/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9960 - val_loss: 1.9699
# Epoch 94/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9679 - val_loss: 2.1497
# Epoch 95/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0692 - val_loss: 3.0569
# Epoch 96/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0329 - val_loss: 2.2716
# Epoch 97/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3796 - val_loss: 2.8245
# Epoch 98/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0981 - val_loss: 2.4544
# Epoch 99/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1166 - val_loss: 2.2780
# Epoch 100/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1382 - val_loss: 1.9773

# %%
# Evaluar el rendimiento de la red neuronal
y_pred_norm = model.predict(X_test_norm)
loss = model.evaluate(X_test_norm, y_test_norm)

# Desnormalizar los resultados finales
y_pred_denorm = scaler_y.inverse_transform(y_pred_norm)
y_test_denorm = scaler_y.inverse_transform(y_test_norm)
# Out:
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000132F204AA70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 18ms/step - loss: 1.9706

# %%
pd.DataFrame(y_test_denorm)
# Out:
#        0     1      2
# 0    1.0  30.0  120.0
# 1    1.0  36.0  120.0
# 2    1.0  10.0  100.0
# 3    1.0  22.0  120.0
# 4    1.0  10.0  125.0
# 5    1.0  14.0  120.0
# 6   10.0  10.0  120.0
# 7    1.0  10.0   80.0
# 8    3.0  10.0  120.0
# 9    1.0   7.0  120.0
# 10   1.0  34.0  120.0
# 11   1.0  10.0   65.0
# 12   1.0  18.0  120.0

# %%
pd.DataFrame(y_pred_denorm)
# Out:
#            0          1           2
# 0   1.062994  29.265596  119.957962
# 1   1.065009  31.700697  119.961998
# 2   1.538611  24.120451   97.043213
# 3   1.053755  18.811722  119.967453
# 4   1.076729  31.631685  120.068108
# 5   1.051522  11.129803  119.929459
# 6   9.381666   8.263309  119.988510
# 7   1.665105  27.857943   91.231232
# 8   2.550591   9.593865  119.975571
# 9   1.051065  11.141669  119.945854
# 10  1.064719  31.549480  119.957253
# 11  1.319354  17.590282  107.153069
# 12  1.049936  12.500491  119.976715

# %%
# Calcular el error medio absoluto (MAE)
mae = mean_absolute_error(y_test_denorm, y_pred_denorm)
print('MAE:', mae)

# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(y_test_denorm, y_pred_denorm)
print('MSE:', mse)

# Calcular el coeficiente de determinación (R^2)
r2 = r2_score(y_test_denorm, y_pred_denorm)
print('R^2:', r2)
# Out:
# MAE: 3.877072181457128
# MSE: 78.85633119029684
# R^2: 0.5330409625641738

# %%
# Graficar la evolución del error a través de las épocas
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
